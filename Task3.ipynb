# %%
#Task 1 - Fitbit Dataset

1. Read this dataset in pandas , mysql and mongodb 
2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
 ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql 
3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
4 . Find out in this data that how many unique id's we have 
5 . which id is one of the active id that you have in whole dataset 
6 . how many of them have not logged there activity find out in terms of number of ids 
7 . Find out who is the laziest person id that we have in dataset 
8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
9. how many person are not a regular person with respect to activity try to find out those 
10 . who is the thired most active person in this dataset find out those in pandas and in sql both . 
11 . who is the 5th most laziest person avilable in dataset find it out 
12 . what is a totla acumulative calories burn for a person find out

# %%
#task 2 - Superstore_USA
1 . load this data in sql and in pandas with a relation in sql 
2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins 

submit your git link for the same 
 
you have to submit this task by next Friday 5th 11PM IST  to respective mail id 
sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %% [raw]
# # Task 1 - Fitbit Dataset

# %%
# 1. Read this dataset in pandas , mysql and mongodb 
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
import pandas as pd
df1=pd.read_csv(r"C:\Users\Aman\Downloads\task\FitBitdata.csv")
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df1.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
# Connecting database
# 2. while creting a table in mysql dont use manual approach to create it,
# always use a automation to create a table in mysql

from sqlalchemy import create_engine
user = 'root'
password = 'admin'
host = 'localhost'
port = 3306
database = 'task'
db=create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")
print("Connection established at",db)
# Out:
# Connection established at Engine(mysql+pymysql://root:***@localhost:3306/task)

# %%
df1.to_sql(con=db,name='fitbit_data',if_exists='append',index=False)
# Out:
# 457

# %%
df1.to_json('FitBit.json')

# %%
import pymongo
import certifi
ca=certifi.where()
client = pymongo.MongoClient("mongodb+srv://admin:Aman@cluster0.a75efai.mongodb.net/?retryWrites=true&w=majority",tlsCAFile=ca)
dbm= client.test
requesting=[]

# %%
import json
from pymongo import InsertOne
dbm=client['Task']
collection3=dbm['fitbit_data']
with open(r"FitBit.json") as data:
    for j in data:
        dt=json.loads(j)
        requesting.append(InsertOne(dt))
result=collection3.bulk_write(requesting)

# %%
for i in collection3.find_one():
    print(i)
# Out:
# _id
# Id
# ActivityDate
# TotalSteps
# TotalDistance
# TrackerDistance
# LoggedActivitiesDistance
# VeryActiveDistance
# ModeratelyActiveDistance
# LightActiveDistance
# SedentaryActiveDistance
# VeryActiveMinutes
# FairlyActiveMinutes
# LightlyActiveMinutes
# SedentaryMinutes
# Calories

# %%
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

df1['ActivityDate']=pd.to_datetime(df1.ActivityDate)
# In sql it is stored  in date format

# %%
# 4 . Find out in this data that how many unique id's we have 
count=df1['Id'].unique()
print(f"The number of unique id's is {len(count)} and ids are \n {count}")
# Out:
# The number of unique id's is 35 and ids are
#  [1503960366 1624580081 1644430081 1844505072 1927972279 2022484408
#  2026352035 2320127002 2347167796 2873212765 2891001357 3372868164
#  3977333714 4020332650 4057192912 4319703577 4388161847 4445114986
#  4558609924 4702921684 5553957443 5577150313 6117666160 6290855005
#  6391747486 6775888955 6962181067 7007744171 7086361926 8053475328
#  8253242879 8378563200 8583815059 8792009665 8877689391]

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# 5 . which id is one of the active id that you have in whole dataset
df1['TotalActiveMinutes']=df1.VeryActiveMinutes+df1.FairlyActiveMinutes+df1.LightlyActiveMinutes
df1.sort_values('TotalActiveMinutes',ascending=False).iloc[[0]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 139  2891001357   2016-04-02        4126           3.22              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 139                  3.218688                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 139                 3.22                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 139                    0                   720               720      2881
#
#      TotalActiveMinutes
# 139                 720

# %%
# 6 . how many of them have not logged there activity find out in terms of number of ids 
ids=df1[df1.TotalActiveMinutes==0].Id
print(f"The number of not logged activities are {len(ids)} and their ids are \n{ids}")
# Out:
# The number of not logged activities are 68 and their ids are
# 51     1844505072
# 52     1844505072
# 59     1844505072
# 96     2320127002
# 97     2320127002
#           ...
# 402    8253242879
# 403    8253242879
# 404    8253242879
# 405    8253242879
# 412    8253242879
# Name: Id, Length: 68, dtype: int64

# %%
# 7 . Find out who is the laziest person id that we have in dataset 
df1[df1.Calories>0].sort_values('Calories').reset_index().iloc[[0]]
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     18  1503960366   2016-04-12         224           0.14             0.14
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 0.0                       0.0
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 0.13                      0.0                  0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                    0                     9                32        50
#
#    TotalActiveMinutes
# 0                   9

# %%
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
# Ans:-
# Most female adults need 1,600–2,200 calories per day, while adult males need 2,200–3,000 calories 
# per day. However, the amount of calories you need each day is unique to your body 
# and activity levels

# considering it 2000 cal

healthy_people=df1[df1['Calories']>2000]['Id']

print(f"No of healthy people in our dataset is {len(healthy_people)} and their ids are \n{healthy_people}")
# Out:
# No of healthy people in our dataset is 254 and their ids are
# 1      1503960366
# 10     1503960366
# 11     1503960366
# 38     1644430081
# 39     1644430081
#           ...
# 451    8877689391
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# Name: Id, Length: 254, dtype: int64

# %%
# 9. how many person are not a regular person with respect to activity try to find out those 
df1[df1.LoggedActivitiesDistance==0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both . 
df1.sort_values('TotalActiveMinutes',ascending=False).iloc[[2]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 142  2891001357   2016-04-05        2063           1.61              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 142                  1.609344                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 142                 1.61                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 142                    0                   630                99      1144
#
#      TotalActiveMinutes
# 142                 630

# %%
# 12 . what is a totla acumulative calories burn for a person find out

df1.groupby('Id',as_index = False).sum()
# Out:
#             Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0   1503960366      221170     144.540001       144.540001
# 1   1624580081       80299      52.189999        52.189999
# 2   1644430081       92748      67.490000        67.490000
# 3   1844505072       43687      28.880000        28.880000
# 4   1927972279       26170      18.130000        18.130000
# 5   2022484408      146099     105.290001       105.290001
# 6   2026352035       40713      25.240000        25.240000
# 7   2320127002       37661      25.470000        25.470000
# 8   2347167796      147001      97.670001        97.670001
# 9   2873212765       79639      53.630001        53.630001
# 10  2891001357        6189       4.830000         0.000000
# 11  3372868164       61275      42.160000        42.160000
# 12  3977333714      103967      69.679999        69.679999
# 13  4020332650      184851     132.600000       132.600000
# 14  4057192912       60391      44.450000        45.020000
# ...

# %%
#task 2 - Superstore_USA

# %%
# 1 . load this data in sql and in pandas with a relation in sql 
# 2 . while loading this data you dont have to create a table manually 
# you can use any automated approach to create a table and load a data in bulk in table 
df2=pd.read_excel(r"C:\Users\Aman\Downloads\task\Superstore_USA.xlsx")
df3=pd.read_excel(r"C:\Users\Aman\Downloads\task\Superstore_USA.xlsx",sheet_name="Returns")
df4=pd.read_excel(r"C:\Users\Aman\Downloads\task\Superstore_USA.xlsx",sheet_name="Users")

# %%
df2.to_sql(con=db,name='superstore_usa',if_exists='append',index=False)
# Out:
# 9426

# %%
# 3 . Find out how  many return that we have recived and with a product id 
df3
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
# 4 . try  to join order and return data both in sql and pandas 
df5=pd.merge(df2,df3,on="Order ID")
df5
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
# 5 . Try to find out how many unique customer that we have 
customer=df5['Customer Name'].unique()
print(f"The number of unique customer is {len(customer)} and names is\n{customer}")
# Out:
# The number of unique customer is 47 and names is
# ['Tony Wilkins Winters' 'Linda Weiss' 'Eleanor Swain' 'Glen Caldwell'
#  'Kim Weiss' 'Michael Wiggins' 'Toni Swanson' 'Kristine Connolly'
#  'Lindsay P Ashley' 'Neal Wolfe' 'Jenny Gold' 'Gail Rankin Cole'
#  'Ernest Oh' 'Erin Ballard' 'Gene Gilliam' 'Timothy Ross'
#  'Maxine Collier Grady' 'Billy Perry Browning' 'Hazel Jennings'
#  'Lois Hansen' 'Harold Albright' 'Katherine Knight' 'Keith Marsh'
#  'Vickie Becker' 'Pamela Wiley' 'Jimmy Han' 'Constance Flowers'
#  'Nina Horne Kelly' 'Bonnie Matthews Rowland' 'Priscilla Kane'
#  'Leigh Burnette Hurley' 'Frank Cross' 'Kara Gregory' 'Wayne Bass'
#  'Amanda Kay' "Rosemary O'Brien" 'Ronnie Dodson' 'Yvonne Mann'
#  'Brian Grady' 'Ruth McConnell Young' 'Dana Teague' 'Andrew Gonzalez'
#  'Maurice Everett' 'Tammy Raynor' 'Gordon Brandt' 'Andrew Levine'
#  'Peter Brooks']

# %%
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
df4
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# 7 . find out how many different differnet shipement mode that we have
# and what is a percentage usablity of all the shipment mode with respect to dataset 
ship_mode=df2['Ship Mode'].unique()
ship_mode_percent=df2.groupby('Ship Mode')["Row ID"].count()*100/9426
print(f"Number of shipment is {ship_mode} and percentage is \n{ship_mode_percent}")
# Out:
# Number of shipment is ['Regular Air' 'Express Air' 'Delivery Truck'] and percentage is
# Ship Mode
# Delivery Truck    13.611288
# Express Air       11.744112
# Regular Air       74.644600
# Name: Row ID, dtype: float64

# %%
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
df2['Diff_between_order_shipment']=pd.to_timedelta(df2['Ship Date']-df2['Order Date'])
df2
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
df2[df2['Diff_between_order_shipment']>='10 days']
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %%
df3
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and 
# find out that region manager as well
# There are No Records in which we have delay in shipment more than 15 days and got returned!!
df2.merge(df3)[['Diff_between_order_shipment']]
# Out:
#    Diff_between_order_shipment
# 0                       4 days
# 1                       2 days
# 2                       2 days
# 3                       2 days
# 4                       0 days
# ..                         ...
# 93                      2 days
# 94                      1 days
# 95                      2 days
# 96                      2 days
# 97                      2 days
#
# [98 rows x 1 columns]

# %%
# 11 . Gorup by region and find out which region is more profitable 
df2.groupby('Region')["Profit"].mean()
# Out:
# Region
# Central    179.312027
# East       164.948094
# South       53.327120
# West       136.098710
# Name: Profit, dtype: float64

# %%
# 12 . Try to find out overalll in which country we are giving more didscount 
df2.groupby('State or Province')["Discount"].mean().sort_values(ascending=False)
# Out:
# State or Province
# Wyoming                 0.054762
# Louisiana               0.054607
# Rhode Island            0.054500
# Utah                    0.052534
# Minnesota               0.052385
# Vermont                 0.052295
# Connecticut             0.052195
# Maine                   0.052031
# Kansas                  0.051805
# Tennessee               0.051506
# California              0.051205
# Arizona                 0.051194
# Kentucky                0.050964
# Illinois                0.050873
# South Carolina          0.050857
# Indiana                 0.050705
# Massachusetts           0.050541
# Florida                 0.050536
# North Dakota            0.050294
# New York                0.050279
# Missouri                0.050248
# West Virginia           0.050233
# Oregon                  0.050119
# Mississippi             0.049872
# Ohio                    0.049773
# Maryland                0.049719
# Oklahoma                0.049712
# Virginia                0.049495
# ...

# %%
# 13 . Give me a list of unique postal code 
list(df2['Postal Code'])
# Out:
# [60101,
#  98221,
#  98221,
#  98221,
#  98221,
#  98221,
#  98221,
#  91776,
#  91776,
#  95123,
#  95123,
#  95123,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  55372,
#  55372,
#  55372,
#  55372,
#  11787,
#  11787,
#  11787,
#  11787,
#  11787,
#  11787,
#  13210,
#  13210,
#  13210,
#  59405,
#  59405,
#  59601,
#  59601,
#  59601,
#  59601,
#  59601,
#  59601,
#  59801,
#  68005,
#  68005,
#  68005,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  10012,
#  92653,
#  92653,
#  92653,
#  92653,
#  92677,
#  92677,
#  92677,
#  92677,
#  92677,
#  92530,
#  92530,
#  92530,
#  92530,
#  92630,
#  92630,
#  92630,
#  92630,
#  90712,
#  90712,
#  90712,
#  90712,
#  90712,
#  90712,
#  93534,
#  93534,
#  90260,
#  90260,
#  97405,
#  97526,
#  97526,
#  97526,
#  97526,
#  97526,
#  97526,
#  97030,
#  97030,
#  97030,
#  97030,
#  97030,
#  97030,
#  97030,
#  97123,
#  97123,
# ...

# %%
# 14 . which customer segement is more profitalble find it out . 
df2.groupby('Customer Segment')['Profit'].mean()
# Out:
# Customer Segment
# Consumer          109.059992
# Corporate         149.789223
# Home Office       122.568892
# Small Business    171.903635
# Name: Profit, dtype: float64

# %%
# 15 . try to find out the 10th most loss making product catagory . 
df2.groupby('Product Sub-Category')['Profit'].sum().reset_index().sort_values('Profit',ascending=True).iloc[9]
# since their are only 3 product category i have considered sub-category
# Out:
# Product Sub-Category    Computer Peripherals
# Profit                          87917.842513
# Name: 4, dtype: object

# %%
# 16 . Try to find out 10 top  product with highest margins 
df2.sort_values(by="Product Base Margin",ascending=False)[['Product Name', 'Product Base Margin']].drop_duplicates().head()
# Out:
#                                            Product Name  Product Base Margin
# 9145                                        Accessory27                 0.85
# 4756                                         Accessory4                 0.85
# 4168                  Sterling Rubber Bands by Alliance                 0.85
# 3994  Office Impressions Heavy Duty Welded Shelving ...                 0.85
# 230                    Belkin OmniView SE Rackmount Kit                 0.85
